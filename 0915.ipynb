# %% [markdown]
# <a href="https://colab.research.google.com/github/gina168651-dot/ai_0915/blob/main/0915.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i="11141203"
j="heiio pyhton"
print(i+j)
# Out:
# 11141203heiio pyhton
