# %% [markdown]
# <a href="https://colab.research.google.com/github/gina168651-dot/ai_0915/blob/main/1013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2021    # a 為變數
print(a)
a += 5
print(a)        # a=+5
a='hello '
q=a+'3'
print(a)       # 會顯示錯誤訊息，文字不可計算
x,y = 20,21 #變數要對稱
print(x,y)
#a=a+a  #相加後可存回a
# Out:
# 2021
# 2026
# hello
# 20 21

# %%
mycal = input('請輸入要計算的數式子：')
print(eval(mycal))     # eval ：計算式子的結果
# Out:
# 請輸入要計算的數式子：6+8+9*8/6
# 26.0

# %%
print('加法程式')
x, y = input('請輸入兩個整數值> ').split()
x = int(x)
y = int(y)
total = x+y
print('答案是', total)
# Out:
# 加法程式
# 請輸入兩個整數值> 77 449
# 答案是 526

# %%
string = '11141203 劉冠伶 企管系 四年級 射手座'
print(string[0::2])
# Out:
# 1110 冠 管 年 手
